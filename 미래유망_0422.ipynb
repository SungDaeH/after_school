# %%
class Student :
    def __init__(self, name, student_id, grade):
        self.name = name
        self.student_id = student_id
        self.grade = grade
        
    def display_info(self):
        print("이름 : ", self.name)
        print("학번 : ", self.student_id)
        print("학년 : ", self.grade)

student1 = Student("홍길동", "2121001", 3)

student1.display_info()
# Out:
# 이름 :  홍길동
# 학번 :  2121001
# 학년 :  3

# %%
class Student :
    def __init__(self, name, student_id, grade):
        self.name = name
        self.student_id = student_id
        self.grade = grade
        
    def display_info(self):
        print("이름 : ", self.name)
        print("학번 : ", self.student_id)
        print("학년 : ", self.grade)

def set_contact():
    name = input("이름: ")
    student_id = input("학번: ")
    grade = input("학년: ")
    print(name, student_id, grade)

def run():
    set_contact()

if __name__ == "__main__":
    run()

# %%
class Student :
    def __init__(self, name, student_id, grade):
        self.name = name
        self.student_id = student_id
        self.grade = grade
        
    def display_info(self):
        print("이름 : ", self.name)
        print("학번 : ", self.student_id)
        print("학년 : ", self.grade)

name = input()
student_id = input()
grade = int(input())

student3 = Student(name, student_id, grade)
student3.display_info()
# Out:
# 황성대
# 060405
# 3
# 이름 :  황성대
# 학번 :  060405
# 학년 :  3

# %%
class Student :
    def __init__(self, name, student_id, grade):
        self.name = name
        self.student_id = student_id
        self.grade = grade
        
    def display_info(self):
        print("이름 : ", self.name)
        print("학번 : ", self.student_id)
        print("학년 : ", self.grade)

    def change_grade(self, new_grade):
        self.grade = new_grade
        
student1 = Student("홍길동", "20210001", 3)

student1.change_grade(2)

student1.display_info()
# Out:
# 이름 :  홍길동
# 학번 :  20210001
# 학년 :  2

# %%
import mod2

print(mod2.add(1,3))
# Out:
# 4

# %%
import mod3
from mod2 import sub
print(mod3.mul(3, 5))
print(sub(3, 2))
# Out:
# 15
# 1

# %%
import mod4

a = mod4.Math()
print(a.solv(2))

print(mod4.PI)
# Out:
# 12.56
# 3.14

# %%
# !pip install folium
# !pip install googlemaps
# !pip install xlrd
# !pip install openpyxl
# Out:
# Collecting folium
#   Downloading folium-0.16.0-py2.py3-none-any.whl (100 kB)
#      -------------------------------------- 100.0/100.0 kB 5.6 MB/s eta 0:00:00
# Collecting xyzservices
#   Downloading xyzservices-2024.4.0-py3-none-any.whl (81 kB)
#      ---------------------------------------- 82.0/82.0 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\lib\site-packages (from folium) (3.1.2)
# Collecting branca>=0.6.0
#   Downloading branca-0.7.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.1 folium-0.16.0 xyzservices-2024.4.0
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\user\anaconda3\lib\site-packages (from googlemaps) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40750 sha256=eeb6306141176d05f541c889ba634d31ac5f6cf23e0d148a02e1b352832e6276
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\ca\e3\07\3a193cac660b6210a88180b659cb251f941cbff99a0f556136
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Requirement already satisfied: openpyxl in c:\users\user\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\user\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import os
import json
import csv
import requests
import folium
import googlemaps
import pandas as pd
import xlrd
import openpyxl
import seaborn as sns

# %matplotlib notebook
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 라이브러리 로드
import os
import json
import csv
import requests
import folium
import googlemaps
import pandas as pd
import xlrd
import openpyxl
import seaborn as sns
import numpy as np
import platform

# %matplotlib notebook
import matplotlib.pyplot as plt
import warnings
from matplotlib import font_manager, rc

# 주피터 에러 메시지 제거
warnings.filterwarnings(action='ignore')

# Plot 한글 지원
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Linux':
    path = "/usr/share/fonts/NanumGothic.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# Google map api key setting 
gmaps_key = "AIzaSyCpN60rYlKTr6l_y1IcEhZu2pvyV_oF4dI" 
gmaps = googlemaps.Client(key=gmaps_key)

# %%
seoul_df = pd.read_excel("내맛집.xlsx",'경기도', engine = 'openpyxl')
seoul_df
# Out:
#     Unnamed: 0 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN        NaN            NaN        NaN        NaN        NaN
# 1          NaN        NaN            NaN        NaN        NaN        NaN
# 2          NaN        NaN            NaN        NaN        NaN        NaN
# 3           지역        도시명           음식종류       대표메뉴       식당상호     포털 검색명
# 4          경기도        가평군  백숙/장어/송어회/매운탕  매운탕/장어/백숙        강마루    삼회리 강마루
# ..         ...        ...            ...        ...        ...        ...
# 212        경기도        화성시             냉면   물냉면.비빔냉면     청학동칡냉면     청학동칡냉면
# 213        경기도        화성시          족발&보쌈         보쌈  유명환 명품 족발      유명환족발
# 214        경기도        화성시           중국음식       꼬막짬뽕    조기종의향미각        향미각
# 215        경기도        화성시             한식       황태정식    하태우노란황태  동탄하태우노란황태
# 216        경기도        화성시             한식        쌀국수       포레스트    동탄 포레스트
#
#                                             Unnamed: 6
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 추천사유
# 4    음식도 정갈하고 모든음식이 맛있다는 점 !! 신랑이 백숙을 먹고 신세계를 맛보았습니...
# ..                                                 ...
# 212             융건릉 관광 후 시원하게 육수가 맛있고 양도 푸짐하며 줄서서먹는 맛집
# 213              야야들 쫄깃한 족발과 막구수가 일품임(점심보쌈정식이 알차고 맛나다)
# 214  매콤한 꼬막짬뽕 국물에 쫄깃만 면이 일품임(각종 해물&소고기 등 재표)현지인들이 많...
# 215                           시원한 황태 해장국과 코다리 구이가 맛있는집
# 216  국물이 시원한 쌀국수 맛집 기본 1시간은 기다려야하며 대기명단에 이름 작성하고 대기...
#
# [217 rows x 7 columns]

# %%
seoul_df.rename(columns = {'Unnamed: 0':'지역',
                            'Unnamed: 1':'도시명',
                            'Unnamed: 2':'음식종류',
                            'Unnamed: 3':'대표 메뉴',
                            'Unnamed: 4':'식당상호',
                            'Unnamed: 5':'포털 검색명',
                            'Unnamed: 6':'추천사유'}, inplace=True)
seoul_df.head()
# Out:
#       지역  도시명  음식종류 대표 메뉴   식당상호   포털 검색명  \
# 0    NaN  NaN   NaN   NaN    NaN      NaN
# 1    NaN  NaN   NaN   NaN    NaN      NaN
# 2    NaN  NaN   NaN   NaN    NaN      NaN
# 3     지역  도시명  음식종류  대표메뉴   식당상호   포털 검색명
# 4  서울특별시  강남구    육류   양꼬치  짱수양꼬치  수서동 양꼬치
#
#                                           추천사유
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                         추천사유
# 4  양꼬치 집과 쌀국수집이 같이 붙어 있어 쌀국수도 같이 즐길 수 있어서 좋았어요

# %%
seoul_df_raw = seoul_df.drop([0,1,2,3])
seoul_df_raw
# Out:
#         지역  도시명 음식종류      대표 메뉴            식당상호      포털 검색명  \
# 4    서울특별시  강남구   육류        양꼬치           짱수양꼬치     수서동 양꼬치
# 5    서울특별시  강남구   일식        돈까스            구찌라꾸        구찌라꾸
# 6    서울특별시  강남구   중식       낙지짬뽕             안사부       안사부짬뽕
# 7    서울특별시  강남구   한식        순대국          농민백암순대      농민백암순대
# 8    서울특별시  강남구   한식         족발              뽕족          뽕족
# ..     ...  ...  ...        ...             ...         ...
# 101  서울특별시  중랑구   한식        해물찜              찜집       찝집 본점
# 102  서울특별시  중랑구   한식      곱창,막창           이주소곱창       이주소곱창
# 103  서울특별시  중랑구   한식  동태탕,코다리조림  동해세수대야 동태탕 상봉점  동해세수대야 동태탕
# 104  서울특별시  중랑구   한식       철판곱창         울타리철판곱창     울타리철판곱창
# 105  서울특별시  중랑구   한식        소고기             고려관      고려관 본점
#
#                                                   추천사유
# 4          양꼬치 집과 쌀국수집이 같이 붙어 있어 쌀국수도 같이 즐길 수 있어서 좋았어요
# 5                 일본식 돈까스 맛집 까스류 뿐아니라 우동 덥밥 등 모든메뉴가 일품
# 6    비주얼과 맛 모두 최고, 내용물을 보면 가성비 최고. 양과 재료, 맛과 비주얼 모두...
# 7             수요미식회에 소개된, 국물이 진하고 건더기가 가득한~!! 순대국 갑오브갑
# 8          비교불가한 부드러움이 특징인 족발로, 부드러운 족발을 좋아하신다면, 뽕족~!!
# ..                                                 ...
# 101                          콩나물 보다 해물이 정말 많이 들어간 해물찜
# 102                 곱창,막창 맛집이며, 최소 30분 이상 대기하셔서 들어갈 맛집
# 103  점장님, 총괄님도 인정하시는 맛집으로 가격대비 맛도 좋아 얼큰한 국물이 생각나면 딱...
# 104                           치즈곱창,야채곱창 식사 후 볶음밥이 맛있는집
# 105                         샐러드바가 있는 가족 모임하기 좋은 소기기 맛집
#
# [102 rows x 7 columns]

# %%
seoul_df_raw.set_index('지역')
# Out:
#        도시명 음식종류      대표 메뉴            식당상호      포털 검색명  \
# 지역
# 서울특별시  강남구   육류        양꼬치           짱수양꼬치     수서동 양꼬치
# 서울특별시  강남구   일식        돈까스            구찌라꾸        구찌라꾸
# 서울특별시  강남구   중식       낙지짬뽕             안사부       안사부짬뽕
# 서울특별시  강남구   한식        순대국          농민백암순대      농민백암순대
# 서울특별시  강남구   한식         족발              뽕족          뽕족
# ...    ...  ...        ...             ...         ...
# 서울특별시  중랑구   한식        해물찜              찜집       찝집 본점
# 서울특별시  중랑구   한식      곱창,막창           이주소곱창       이주소곱창
# 서울특별시  중랑구   한식  동태탕,코다리조림  동해세수대야 동태탕 상봉점  동해세수대야 동태탕
# 서울특별시  중랑구   한식       철판곱창         울타리철판곱창     울타리철판곱창
# 서울특별시  중랑구   한식        소고기             고려관      고려관 본점
#
#                                                     추천사유
# 지역
# 서울특별시        양꼬치 집과 쌀국수집이 같이 붙어 있어 쌀국수도 같이 즐길 수 있어서 좋았어요
# 서울특별시               일본식 돈까스 맛집 까스류 뿐아니라 우동 덥밥 등 모든메뉴가 일품
# 서울특별시  비주얼과 맛 모두 최고, 내용물을 보면 가성비 최고. 양과 재료, 맛과 비주얼 모두...
# 서울특별시           수요미식회에 소개된, 국물이 진하고 건더기가 가득한~!! 순대국 갑오브갑
# 서울특별시        비교불가한 부드러움이 특징인 족발로, 부드러운 족발을 좋아하신다면, 뽕족~!!
# ...                                                  ...
# 서울특별시                          콩나물 보다 해물이 정말 많이 들어간 해물찜
# 서울특별시                 곱창,막창 맛집이며, 최소 30분 이상 대기하셔서 들어갈 맛집
# 서울특별시  점장님, 총괄님도 인정하시는 맛집으로 가격대비 맛도 좋아 얼큰한 국물이 생각나면 딱...
# 서울특별시                           치즈곱창,야채곱창 식사 후 볶음밥이 맛있는집
# 서울특별시                         샐러드바가 있는 가족 모임하기 좋은 소기기 맛집
#
# [102 rows x 6 columns]

# %%
gmaps.geocode('짱수양꼬치', language='ko')
# Out:
# []

# %%
[{'address_components': [{'long_name': '２６',
    'short_name': '２６',
    'types': ['premise']},
   {'long_name': '서운로6길',
    'short_name': '서운로6길',
    'types': ['political', 'sublocality', 'sublocality_level_4']},
   {'long_name': '서초2동',
    'short_name': '서초2동',
    'types': ['political', 'sublocality', 'sublocality_level_2']},
   {'long_name': '서초구',
    'short_name': '서초구',
    'types': ['political', 'sublocality', 'sublocality_level_1']},
   {'long_name': '서울특별시',
    'short_name': '서울특별시',
    'types': ['administrative_area_level_1', 'political']},
   {'long_name': '대한민국',
    'short_name': 'KR',
    'types': ['country', 'political']},
   {'long_name': '137-070',
    'short_name': '137-070',
    'types': ['postal_code']}],
  'formatted_address': '대한민국 서울특별시 서초구 서초2동 서운로6길 26',
  'geometry': {'location': {'lat': 37.4854992, 'lng': 127.0308151},
   'location_type': 'ROOFTOP',
   'viewport': {'northeast': {'lat': 37.4868481802915,
     'lng': 127.0321640802915},
    'southwest': {'lat': 37.4841502197085, 'lng': 127.0294661197085}}},
  'place_id': 'ChIJJc-C7UihfDURyy9QlrEhpZ0',
  'types': ['establishment', 'food', 'point_of_interest', 'restaurant']}]
# Out:
# [{'address_components': [{'long_name': '２６',
#     'short_name': '２６',
#     'types': ['premise']},
#    {'long_name': '서운로6길',
#     'short_name': '서운로6길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '서초2동',
#     'short_name': '서초2동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '137-070',
#     'short_name': '137-070',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서초구 서초2동 서운로6길 26',
#   'geometry': {'location': {'lat': 37.4854992, 'lng': 127.0308151},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37
# 104  서울특별시  중랑구   한식       철판곱창         울타리철판곱창     울타리철판곱창
# 105  서울특별시  중랑구   한식        소고기             고려관      고려관 본점
#
#                                                   추천사유        lat         lng
# 4          양꼬치 집과 쌀국수집이 같이 붙어 있어 쌀국수도 같이 즐길 수 있어서 좋았어요  37.485499  127.030815
# 5                 일본식 돈까스 맛집 까스류 뿐아니라 우동 덥밥 등 모든메뉴가 일품  37.487269  127.103126
# 6    비주얼과 맛 모두 최고, 내용물을 보면 가성비 최고. 양과 재료, 맛과 비주얼 모두...  37.502372  127.036722
# 7             수요미식회에 소개된, 국물이 진하고 건더기가 가득한~!! 순대국 갑오브갑  37.503706  127.053037
# 8          비교불가한 부드러움이 특징인 족발로, 부드러운 족발을 좋아하신다면, 뽕족~!!  37.497394  127.030232
# ..                                                 ...        ...         ...
# 101                          콩나물 보다 해물이 정말 많이 들어간 해물찜   37.578541  127.085923
# 102                 곱창,막창 맛집이며, 최소 30분 이상 대기하셔서 들어갈 맛집  37.551891  126.991794
# 103  점장님, 총괄님도 인정하시는 맛집으로 가격대비 맛도 좋아 얼큰한 국물이 생각나면 딱...  37.597118  127.094573
# 104                           치즈곱창,야채곱창 식사 후 볶음밥이 맛있는집  37.510502  127.023511
# 105                         샐러드바가 있는 가족 모임하기 좋은 소기기 맛집  37.551891  126.991794
#
# [102 rows x 9 columns]

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for n in seoul_df_raw.index:
    folium.Marker(
        [seoul_df_raw['lat'][n],seoul_df_raw['lng'][n]],
        radius = 10, 
        color='#3186cc',
        fill_color='#3186cc', 
        fill=True,
        tooltip  = ('<b>- 지역</b>: ' + seoul_df_raw['지역'][n] + " " + seoul_df_raw['도시명'][n] + '<br>' +
                 '<b>- 상호명</b>: ' + seoul_df_raw['식당상호'][n] + '<br>' + 
                 '<b>- 대표메뉴</b>: ' + seoul_df_raw['대표 메뉴'][n] + '<br>' + 
                   '<b>- 추천사유</b>: ' + seoul_df_raw['추천사유'][n])
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4c4d10d726322b5597ef2593cdb508d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4c4d10d726322b5597ef2593cdb508d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4c4d10d726322b5597ef2593cdb508d = L.map(
#                 &quot;map_a4c4d10d726322b5597ef2593cdb508d&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edf27209d269c4c33e09bcc0b4b652d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_edf27209d269c4c33e09bcc0b4b652d0.addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             var marker_0eb323cc6a060324bb6d06dbb513f1c9 = L.marker(
#                 [37.4854992, 127.0308151],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             marker_0eb323cc6a060324bb6d06dbb513f1c9.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울특별시 강남구&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 짱수양꼬치&lt;br&gt;&lt;b&gt;- 대표메뉴&lt;/b&gt;: 양꼬치&lt;br&gt;&lt;b&gt;- 추천사유&lt;/b&gt;: 양꼬치 집과 쌀국수집이 같이 붙어 있어 쌀국수도 같이 즐길 수 있어서 좋았어요
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7fa94df3303422a16c194fb4325549ec = L.marker(
#                 [37.487269, 127.1031262],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             marker_7fa94df3303422a16c194fb4325549ec.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울특별시 강남구&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 구찌라꾸&lt;br&gt;&lt;b&gt;- 대표메뉴&lt;/b&gt;: 돈까스&lt;br&gt;&lt;b&gt;- 추천사유&lt;/b&gt;: 일본식 돈까스 맛집 까스류 뿐아니라 우동 덥밥 등 모든메뉴가 일품
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25d644b3d7d2fd156fc8a1d5daca0358 = L.marker(
#                 [37.5023717, 127.0367225],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             marker_25d644b3d7d2fd156fc8a1d5daca0358.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울특별시 강남구&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 안사부&lt;br&gt;&lt;b&gt;- 대표메뉴&lt;/b&gt;: 낙지짬뽕&lt;br&gt;&lt;b&gt;- 추천사유&lt;/b&gt;: 비주얼과 맛 모두 최고, 내용물을 보면 가성비 최고. 양과 재료, 맛과 비주얼 모두 최고~!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_43fbbd28a8aada20ae3dc20160c50783 = L.marker(
#                 [37.5037065, 127.0530366],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             marker_43fbbd28a8aada20ae3dc20160c50783.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울특별시 강남구&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 농민백암순대&lt;br&gt;&lt;b&gt;- 대표메뉴&lt;/b&gt;: 순대국&lt;br&gt;&lt;b&gt;- 추천사유&lt;/b&gt;: 수요미식회에 소개된, 국물이 진하고 건더기가 가득한~!! 순대국 갑오브갑
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a2e0d3cef1105301b86102ee374f52 = L.marker(
#                 [37.4973943, 127.0302323],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             marker_00a2e0d3cef1105301b86102ee374f52.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울특별시 강남구&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 뽕족&lt;br&gt;&lt;b&gt;- 대표메뉴&lt;/b&gt;: 족발&lt;br&gt;&lt;b&gt;- 추천사유&lt;/b&gt;: 비교불가한 부드러움이 특징인 족발로, 부드러운 족발을 좋아하신다면, 뽕족~!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6e56992716593c06d5dc5405191cf22 = L.marker(
#                 [37.5117913, 127.0547593],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_a4c4d10d726322b5597ef2593cdb508d);
#
#
#             marker_e6e56992716593c06d5dc5405191cf22.bindTooltip(
#                 `&lt;div&g

# %%
hp = pd.read_csv("fulldata_01_01_01_P_병원.csv", encoding='cp949')
hp
# Out:
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                       관리번호  \
# 0        1     병원  01_01_01_P   5340000  PHMA220125340030021200003
# 1        2     병원  01_01_01_P   5340000  PHMA220135340030021200001
# 2        3     병원  01_01_01_P   5340000  PHMA220165340030021200001
# 3        4     병원  01_01_01_P   5380000  PHMA219895380021021200001
# 4        5     병원  01_01_01_P   5410000  PHMA220185410012021200001
# ...    ...    ...         ...       ...                        ...
# 8581  8582     병원  01_01_01_P   6290000         200262900002000011
# 8582  8583     병원  01_01_01_P   6290000         198262900002000001
# 8583  8584     병원  01_01_01_P   6290000         198762900002000003
# 8584  8585     병원  01_01_01_P   6500000         200464900002000001
# 8585  8586     병원  01_01_01_P   6500000         200765000002000003
#
#            인허가일자  인허가취소일자  영업상태구분코드  영업상태명 상세영업상태코드  ... 완화의료지정형태 완화의료담당부서명  \
# 0     2012-11-30      NaN         1  영업/정상       13  ...      NaN       NaN
# 1     2013-11-11      NaN         1  영업/정상       13  ...      NaN       NaN
# 2     2016-01-28      NaN         1  영업/정상       13  ...      NaN       NaN
# 3     1989-03-31      NaN         1  영업/정상       13  ...      NaN       NaN
# 4     2018-03-16      NaN         1  영업/정상       13  ...      NaN       NaN
# ...          ...      ...       ...    ...      ...  ...      ...       ...
# 8581  2002-11-12      NaN         3     폐업        3  ...      NaN       NaN
# 8582  1982-03-06      NaN         3     폐업        3  ...      NaN       NaN
# 8583  1987-12-30      NaN         3     폐업        3  ...      NaN       NaN
# 8584  2004-04-20      NaN         3     폐업        3  ...      NaN       NaN
# 8585  2007-03-27      NaN         3     폐업        3  ...      NaN       NaN
#
#      구급차특수 구급차일반  총인원 구조사수  허가병상수 최초지정일자     관리주체 Unnamed: 45
# 0        0     0  NaN  NaN      0    NaN      시군구         NaN
# 1        0     0  NaN  NaN      0    NaN      시군구         NaN
# 2        0     0  NaN  NaN      0    NaN      시군구         NaN
# 3        0     0  NaN  NaN      0    NaN      시군구         NaN
# 4        0     0  NaN  NaN      0    NaN      시군구         NaN
# ...    ...   ...  ...  ...    ...    ...      ...         ...
# 8581     0     0  NaN  NaN      0    NaN  시군구(위임)         NaN
# 8582     0     0  NaN  NaN      0    NaN  시군구(위임)         NaN
# 8583     0     0  NaN  NaN      0    NaN  시군구(위임)         NaN
# 8584     0     0  NaN  NaN      0    NaN  시군구(위임)         NaN
# 8585     0     0  NaN  NaN      0    NaN  시군구(위임)         NaN
#
# [8586 rows x 46 columns]
